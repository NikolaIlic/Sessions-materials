# %% [markdown]
# ![SL1.png](attachment:e5a30be3-0377-4896-b6e6-3427cfacfbed.png)

# %% [markdown]
# ![SL2.png](attachment:db0caa78-27d6-4b0f-b321-d481386bb206.png)

# %% [markdown]
# ![SL3.png](attachment:af7355ed-b534-4910-acc0-12ed7679ab52.png)

# %% [markdown]
# ![SL4.png](attachment:f9c444e3-1f1f-4c33-b674-39fba5ac64ce.png)

# %% [markdown]
# ![SL5.png](attachment:0c593f36-c37a-4310-8dc3-760794ee8608.png)

# %% [markdown]
# ![SL6.png](attachment:3985d42f-9e13-413f-9567-d8cc98d9a74c.png)

# %% [markdown]
# ![SL7.png](attachment:dc358e47-dd17-48f3-bc9e-4bcb7ade5c13.png)

# %% [markdown]
# ![SL8.png](attachment:42f3ebcd-53ef-48a1-a357-4561911e87ff.png)

# %% [markdown]
# ![SL9.png](attachment:06632533-ca23-4663-a282-ddc6280e6fd8.png)

# %% [markdown]
# ![SL10.png](attachment:94fea01e-79f9-456b-ac28-c01a60b98bf0.png)

# %% [markdown]
# # [**Semantic Link Labs Docs**](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.html)

# %% [markdown]
# ## **00. Install semantic link and semantic-link-labs**

# %%
! pip install semantic-link #only for Spark 3.3 or below
! pip install semantic-link-labs
# Out:
# StatementMeta(, b24b4006-0ac7-4c7f-b529-0adaf3c94166, 3, Finished, Available, Finished)
# Collecting semantic-link
#   Downloading semantic_link-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting semantic-link-sempy==0.11.0 (from semantic-link)
#   Downloading semantic_link_sempy-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting semantic-link-functions-geopandas==0.11.0 (from semantic-link)
#   Downloading semantic_link_functions_geopandas-0.11.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting semantic-link-functions-holidays==0.11.0 (from semantic-link)
#   Downloading semantic_link_functions_holidays-0.11.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-link-functions-meteostat==0.11.0 (from semantic-link)
#   Downloading semantic_link_functions_meteostat-0.11.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting semantic-link-functions-phonenumbers==0.11.0 (from semantic-link)
#   Downloading semantic_link_functions_phonenumbers-0.11.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-link-functions-validators==0.11.0 (from semantic-link)
#   Downloading semantic_link_functions_validators-0.11.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting geopandas (from semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting folium (from semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading folium-0.19.6-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting mapclassify (from semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: holidays in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-functions-holidays==0.11.0->semantic-link) (0.48)
# Collecting meteostat (from semantic-link-functions-meteostat==0.11.0->semantic-link)
#   Downloading meteostat-1.6.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting phonenumbers (from semantic-link-functions-phonenumbers==0.11.0->semantic-link)
#   Downloading phonenumbers-9.0.5-py2.py3-none-any.whl.metadata (11 kB)
# Collecting validators (from semantic-link-functions-validators==0.11.0->semantic-link)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (2023.10.3)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (2.1.4)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.11.0->semantic-link) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.11.0->semantic-link) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.11.0->semantic-link) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.11.0->semantic-link) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.11.0->semantic-link) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.11.0->semantic-link) (1.9.3)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy==0.11.0->semantic-link) (1.16.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (4.8.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.11.0->semantic-link) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.11.0->semantic-link) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.11.0->semantic-link) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy==0.11.0->semantic-link) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy==0.11.0->semantic-link) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.11.0->semantic-link) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.11.0->semantic-link) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.11.0->semantic-link) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.11.0->semantic-link) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy==0.11.0->semantic-link) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.11.0->semantic-link) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.11.0->semantic-link) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.11.0->semantic-link) (2.2.0)
# Collecting branca>=0.6.0 (from folium->semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.11.0->semantic-link) (3.1.3)
# Requirement already satisfied: xyzservices in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.11.0->semantic-link) (2022.9.0)
# Collecting pyogrio>=0.7.2 (from geopandas->semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading pyogrio-0.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from geopandas->semantic-link-functions-geopandas==0.11.0->semantic-link) (23.1)
# Collecting pyproj>=3.3.0 (from geopandas->semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading pyproj-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas->semantic-link-functions-geopandas==0.11.0->semantic-link)
#   Downloading shapely-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: networkx>=2.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from mapclassify->semantic-link-functions-geopandas==0.11.0->semantic-link) (3.1)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy==0.11.0->semantic-link) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.11.0->semantic-link) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy==0.11.0->semantic-link) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->semantic-link-sempy==0.11.0->semantic-link) (1.16.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.11.0->semantic-link) (0.2.2)
# Downloading semantic_link-0.11.0-py3-none-any.whl (10 kB)
# Downloading semantic_link_functions_geopandas-0.11.0-py3-none-any.whl (4.0 kB)
# Downloading semantic_link_functions_holidays-0.11.0-py3-none-any.whl (4.2 kB)
# Downloading semantic_link_functions_meteostat-0.11.0-py3-none-any.whl (4.5 kB)
# Downloading semantic_link_functions_phonenumbers-0.11.0-py3-none-any.whl (4.3 kB)
# Downloading semantic_link_functions_validators-0.11.0-py3-none-any.whl (4.8 kB)
# Downloading semantic_link_sempy-0.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 194.4 MB/s eta 0:00:00
# Downloading folium-0.19.6-py2.py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 55.2 MB/s eta 0:00:00
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 114.1 MB/s eta 0:00:00
# Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 28.2 MB/s eta 0:00:00
# Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Downloading phonenumbers-9.0.5-py2.py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 224.2 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 20.9 MB/s eta 0:00:00
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading pyogrio-0.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 158.6 MB/s eta 0:00:0000:0100:01
# Downloading pyproj-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 254.8 MB/s eta 0:00:0000:01
# Downloading shapely-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 229.0 MB/s eta 0:00:00
# Installing collected packages: phonenumbers, validators, shapely, pyproj, pyogrio, branca, meteostat, mapclassify, geopandas, folium, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.9.3
#     Uninstalling semantic-link-sempy-0.9.3:
#       Successfully uninstalled semantic-link-sempy-0.9.3
# Successfully installed branca-0.8.1 folium-0.19.6 geopandas-1.0.1 mapclassify-2.8.1 meteostat-1.6.8 phonenumbers-9.0.5 pyogrio-0.11.0 pyproj-3.7.1 semantic-link-0.11.0 semantic-link-functions-geopandas-0.11.0 semantic-link-functions-holidays-0.11.0 semantic-link-functions-meteostat-0.11.0 semantic-link-functions-phonenumbers-0.11.0 semantic-link-functions-validators-0.11.0 semantic-link-sempy-0.11.0 shapely-2.1.1 validators-0.35.0
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.9.11-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: semantic-link-sempy>=0.10.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-labs) (0.11.0)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-labs) (3.1.1)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.10.2->semantic-link-labs) (8.2.3)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (8.1.2)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.0.0)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.25.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.9.3)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.16.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.10)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.8.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (42.0.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->semantic-link-sempy>=0.10.2->semantic-link-labs) (1.16.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.10.2->semantic-link-labs) (0.2.2)
# Downloading semantic_link_labs-0.9.11-py3-none-any.whl (713 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 713.5/713.5 kB 44.2 MB/s eta 0:00:00
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 19.5 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: polib, jsonpath_ng, anytree, semantic-link-labs
# Successfully installed anytree-2.13.0 jsonpath_ng-1.7.0 polib-1.2.0 semantic-link-labs-0.9.11

# %% [markdown]
# ## **0. Import Sempy and Semantic Link Labs**

# %%
import sempy.fabric as fabric
import sempy_labs as labs

labs.list_connections()

# %% [markdown]
# ## **01. Scenario-based**

# %% [markdown]
# ### [**1. Capacity migration**](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Capacity%20Migration.ipynb)

# %% [markdown]
# ##### **Requirements**
# - Must have an Azure Subscription
# - Must register an App
#   - Permissions: Will need the Contributor role at the scope where the resources will be created, which is often the subscription level
# - Azure Key Vault
#   - Set up within the Azure Subscription
#   - Save secrets for the Tenant ID, Client ID (Application ID), Client Secret
#   - Permissions: Ensure the user who will be executing the notebooks has “Key Vault Secrets User”
# - Fabric Permissions
#   - User should be a tenant admin. This ensures they have the necessary authority to execute and manage the notebooks without encountering permission issues.
#
# ##### **Result**
# - F skus are created for each (specified) capacity
#   - Within the same region as the P SKU
#   - Equivalent SKU size as the P SKU
#   - Same admins as listed on the P SKU
#   - All workspaces are migrated to the corresponding new capacity
# - The names of the newly created F SKU capacities will be an alphanumeric lowercase version of the P SKU capacity name, suffixed with 'fsku'. As an example: "My capacity_3!" -> "mycapacity3fsku".

# %% [markdown]
# ### [**2. Migration to Direct Lake**](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Migration%20to%20Direct%20Lake.ipynb)

# %% [markdown]
# ### [**3. Delta Analyzer**](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Delta%20Analyzer.ipynb)

# %% [markdown]
# ### [**4. Backup, copy and restore a semantic model to a new workspace**](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Semantic%20Model%20Management.ipynb)

# %% [markdown]
# ##### Prerequisites
# - Create an ADLS Gen2 storage account (in the Azure Portal)
# - Assign the ADLS Gen2 storage account to both source and target workspaces
#   - Navigate to your workspace.
#   - Select 'Workspace settings'.
#   - Select 'Azure connections'.
#   - Within 'Azure Data Lake Gen2 Storage' click 'Configure'.
#   - Enter your Subscription, Resource Group and Storage Account.
#   - Click 'Save'.

# %% [markdown]
# ### [**5. Manage semantic model refresh (refresh tables, partitions, view history...)**](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Semantic%20Model%20Refresh.ipynb)

# %% [markdown]
# ## **02. Admin package**

# %% [markdown]
# - Add/Delete user to/from a workspace
# - Assign workspace(s) to a domain
# - Assign workspaces to a capacity
# - Create domains/tags
# - Export Dataflow definition as a JSON file
# - **List of permission details that the specified user can access**
# - **List of activity events in the Fabric tenant**
# - List of users that have access to the specified app
# - List of capacities and their properties
# - List of delegated tenant settings
# - **List of users that have access to the specified workspace**
# - **List of users that have access to the specified semantic model**
# - List external data shares
# - List reports, report subscriptions, users that have access to the specified report...
# - Restore deleted workspace

# %%
labs.admin.list_access_entities ("nikola@nikolailic.onmicrosoft.com")

# %%
labs.admin.list_activity_events (start_time="2025-05-26T07:00:00", end_time="2025-05-26T10:00:00")
# can be filtered by activity and/or user_id

# %%
labs.admin.list_workspace_access_details ("Data Mozart")

# %%
labs.admin.list_items ()

# %% [markdown]
# ## **03. Lakehouse package**

# %% [markdown]
# - Create/Delete OneLake shortcut
# - Create/Delete a lakehouse
# - **Get lakehouse tables/columns**
# - **Check if the table is V-ordered**
# - **List shortcuts**
# - Load table to a lakehouse (currently only files are supported, not folders)
# - **Optimize lakehouse tables**
# - Recover deleted lakehouse object (up to 7 days)
# - Reset shortcut cache
# - Run table maintenance (Optimize = false -> true; v_order = false-> true; vacuum = false -> true; retention period...)

# %%
labs.lakehouse.get_lakehouse_columns ("LH_Demo")

# %%
labs.lakehouse.is_v_ordered("aw_DimProduct")

# %%
labs.lakehouse.list_shortcuts()

# %%
labs.lakehouse.optimize_lakehouse_tables("aw_DimProduct")

# %% [markdown]
# ## **04. Migration package**

# %% [markdown]
# - Create Power Query Template (.pqt) file
# - Migrate DAX calc tables to Delta tables in the lakehouse

# %% [markdown]
# ## **05. Direct Lake package**

# %% [markdown]
# - Add table to Direct Lake model
# - **Check fallback reason**
# - Schema compare/Schema sync
# - Generate shared expressions (dynamically generates the M expression used by a DL model)
# - List unsupported Direct Lake objects
# - Update Direct Lake model connection
# - **Refresh DL model and puts the column that were previously in memory back into memory**

# %%
labs.directlake.check_fallback_reason("S1")

# %%
labs.directlake.warm_direct_lake_cache_isresident("S1")

# %% [markdown]
# ## **06. Report package**

# %% [markdown]
# <mark>### _!!Most of the functions require PBIR format!!_</mark>

# %% [markdown]
# - Disable "Show items with no data"
# - Get/Set report theme
# - **Hide tooltip and drillthrough pages**
# - List bookmarks, page/report filters, pages, report-level measures, semantic model objects...
# - Migrate report-level measures to semantic model
# - Remove unused custom visuals
# - Set page visibility

# %% [markdown]
# #### **0. Initialize ReportWrapper object and then perform various methods (report must be in PBIR format!)**

# %%
import sempy_labs.report as rpt
from sempy_labs.report import ReportWrapper

report = ReportWrapper(report='End-To-End Collisions NYC grey v2_PBIR', workspace=None)

# %%
report.hide_tooltip_drillthrough_pages()

# %%
report.list_pages()

# %% [markdown]
# #### **01. Other Report package functions**

# %% [markdown]
# - Clone report
# - Download report (.pbix)
# - Export report
# - **Launch report in the notebook!**
# - **Rebind report to another semantic model**
# - **Run BPA**

# %%
labs.report.launch_report(report='End-To-End Collisions NYC grey')

# %%
# Rebinds an individual report
labs.report.report_rebind(report='End-To-End Collisions NYC grey', dataset='<Name of the semantic model>', report_workspace= '', dataset_workspace = '')

# Rebinds all report across all workspaces from Model A to Model B
labs.report.report_rebind_all(report='End-To-End Collisions NYC grey'
, new_dataset='<Name of the new semantic model (Model B)>'
, dataset_workspace = '<Workspace of the original semantic model (Model A)>'
, new_dataset_workpace= '<Workspace of the new semantic model (Model B)>'
)

# %%
labs.report.run_report_bpa (report='End-To-End Collisions NYC grey v2_PBIR')

# %% [markdown]
# ## **07. TOM package**

# %% [markdown]
# #### **0. Initialize TOM Wrapper object and then perform various methods**

# %%
from sempy_labs.tom import connect_semantic_model

model = labs.tom.connect_semantic_model(dataset='End-To-End Collisions NYC grey_PBIPR', workspace=None)
# Out:
# StatementMeta(, d652fa55-d379-4308-b1eb-3259f62ba067, 8, Finished, Available, Finished)

# %% [markdown]
# - Add calculated column/calculated table/Calculation group/perspective/relationship
# - Add entity partition
# - Add expression
# - Add Incremental refresh policy
# - Add role/role member
# - Add translation
# - Copy object from Model A to Model B
# - Column size

# %% [markdown]
# ## **08. Miscellanous functions**

# %% [markdown]
# #### **1. Plot table dependencies**

# %%
from sempy.dependencies import plot_dependency_metadata

dataset = "S1"
sales = fabric.read_table(dataset, "aw_FactInternetSales")

dependencies = sales.find_dependencies()

plot_dependency_metadata(dependencies)

# %% [markdown]
# #### **2. Visualize measure dependencies**

# %%
labs.measure_dependency_tree (dataset = 'End-To-End Collisions NYC grey', measure_name='Cyclists Injured')

# %% [markdown]
# #### **3. Translate the entire semantic model**

# %%
labs.translate_semantic_model (dataset = 'End-To-End Collisions NYC grey', languages='da-DK')

# %% [markdown]
# #### **4. Get dataset refresh history**

# %%
labs.get_semantic_model_refresh_history (dataset='CMS_DL', workspace='DP-600 Playground')

# %% [markdown]
# #### **5. Get model size**

# %%
labs.get_semantic_model_size(dataset='CMS Import', workspace= 'DP-600 Playground')

# %% [markdown]
# #### **6. Dynamically generate Direct Lake model based on tables in the Lakehouse**

# %%
labs.directlake.generate_direct_lake_semantic_model (dataset='Name of the Direct Lake dataset'
 , lakehouse_tables='all tables to add'
 , workspace='workspace for the DL model'
 , lakehouse='lakehouse that stores tables'
 , lakehouse_workspace= 'workspace of the lakehouse'
 , overwrite= 'if TRUE, overwrites the existing model'
 , refresh='if TRUE, refreshes the newly created DL model')

# %% [markdown]
# #### **7. Export report (to PDF for example)**

# %%
labs.report.export_report (report='End-To-End Collisions NYC grey_PBIPR',export_format='pdf', file_name='reportexport')

# %% [markdown]
# #### **8. Check if the report is broken**

# %%
#list all semantic model objects and check if they are valid
df = labs.list_report_semantic_model_objects(dataset='End-To-End Collisions NYC grey v2_PBIR', extended=True)
display(df)

# %%
#let's break something:)
with connect_semantic_model(dataset='End-To-End Collisions NYC grey v2_PBIR', readonly = False) as tom:
    m = tom.model.Tables['_Measures'].Measures['Cyclists Injured %']
    m.Name = 'Cyclists Injured Break'

# %%
#Let's check again
df = labs.list_report_semantic_model_objects(dataset='End-To-End Collisions NYC grey v2_PBIR', extended=True)
display(df)

# %% [markdown]
# #### **9. VertiPaq Analyzer**

# %%
labs.vertipaq_analyzer(dataset='End-To-End Collisions NYC grey_PBIPR', workspace='Data Mozart')

# %% [markdown]
# #### **10. Check usage of semantic model objects**

# %%
labs.list_semantic_model_object_report_usage (dataset='End-To-End Collisions NYC grey_PBIPR', workspace=None, include_dependencies= True, extended=True)

# %% [markdown]
# #### **11. Create various Fabric items: pipelines, eventhouses, eventstreams, notebooks, warehouse, lakehouse...**

# %% [markdown]
# #### **12. Export semantic model to OneLake**

# %%
labs.export_model_to_onelake (dataset='', workspace='', destination_lakehouse='creates shortcuts to models delta tables', destination_workspace='')

# %% [markdown]
# #### **13. Refresh semantic model**

# %%
sempy_labs.refresh_semantic_model (dataset=''
, tables=''
, partitions=''
, refresh_type='full, clearValues, calculate, dataOnly, automatic, defragment'
, retry_count=0
, apply_refresh_policy=True
, max_parallelism=10
, workspace=None
, visualize=True
)

# %% [markdown]
# #### **14. Resume/Suspend Fabric capacity**

# %%
sempy_labs.resume_fabric_capacity (capacity_name=''
, azure_subscription_id=''
, resource_group= ''
, key_vault_uri=''
, key_vault_tenant_id=''
, key_vault_client_id=''
, key_vault_client_secret=''
)

#sempy_labs.suspend_fabric_capacity

# %% [markdown]
# ![SL11.png](attachment:9dafa2e4-cc78-484e-bc1e-8d4ba2d807e8.png)

# %% [markdown]
# ![SL12.png](attachment:b5b41aa8-a932-45b9-99ac-f5aa2bb303c6.png)
